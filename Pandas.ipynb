# %% [markdown]
# #PANDAS PRACTICE USING MY SQL DATABASE OF MARVEL & DC

# %% [markdown]
# Q1: TOP 5 MARVEL  movies by BOX OFFICE

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)


df_marvel.sort_values(by="BoxOffice", ascending=False).head(5)
# Out:
#     movieid                    title        director  year  BoxOffice
# 21       22        Avengers: Endgame  Russo Brothers  2019     2797.8
# 18       19   Avengers: Infinity War  Russo Brothers  2018     2048.4
# 5         6             The Avengers     Joss Whedon  2012     1518.8
# 10       11  Avengers: Age of Ultron     Joss Whedon  2015     1405.4
# 17       18            Black Panther    Ryan Coogler  2018     1347.1

# %% [markdown]
# q2 Show all dc movies released after 2015

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)



display(df_dc[df_dc["year"]>2015])
# Out:
#     movieid                               title                             director  year  BoxOffice
# 6         7  Batman v Superman: Dawn of Justice                          Zack Snyder  2016      873.0
# 7         8                       Suicide Squad                           David Ayer  2016      747.0
# 8         9                        Wonder Woman                        Patty Jenkins  2017      822.0
# 9        10                      Justice League  Zack Snyder (credited: Joss Whedon)  2017      657.0
# 10       11                             Aquaman                            James Wan  2018     1148.0
# 11       12                             Shazam!                    David F. Sandberg  2019      366.0
# 12       13                               Joker                        Todd Phillips  2019     1074.0

# %% [markdown]
# q3 : All Unique marvel directors

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)

#all unique directors of marvel 

df_marvel["director"].unique()
# Out:
# array(['Jon Favreau', 'Louis Leterrier', 'Kenneth Branagh',
#        'Joe Johnston', 'Joss Whedon', 'Shane Black', 'Alan Taylor',
#        'Russo Brothers', 'James Gunn', 'Peyton Reed', 'Scott Derrickson',
#        'Jon Watts', 'Taika Waititi', 'Ryan Coogler',
#        'Anna Boden & Ryan Fleck', 'John Watts'], dtype=object)

# %% [markdown]
# q: count of movies per director

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)

df_marvel["director"].value_counts()
# Out:
# director
# Russo Brothers             4
# Jon Favreau                2
# Joss Whedon                2
# James Gunn                 2
# Peyton Reed                2
# Kenneth Branagh            1
# Joe Johnston               1
# Louis Leterrier            1
# Alan Taylor                1
# Shane Black                1
# Scott Derrickson           1
# Jon Watts                  1
# Taika Waititi              1
# Ryan Coogler               1
# Anna Boden & Ryan Fleck    1
# John Watts                 1
# Name: count, dtype: int64

# %% [markdown]
# Merge Marvel dataframe with its info

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)

marvel_full = pd.merge(df_marvel, df_minfo, on="movieid", how = "left")
display(marvel_full)
# Out:
#     movieid                                title                 director  year  BoxOffice               verdict       cinematographer
# 0         1                             Iron Man              Jon Favreau  2008      585.8              Superhit     Matthew Libatique
# 1         2                  The Incredible Hulk          Louis Leterrier  2008      264.8               Average     Peter Menzies Jr.
# 2         3                           Iron Man 2              Jon Favreau  2010      623.9                   Hit     Matthew Libatique
# 3         4                                 Thor          Kenneth Branagh  2011      449.3                   Hit    Haris Zambarloukos
# 4         5   Captain America: The First Avenger             Joe Johnston  2011      370.6                   Hit        Shelly Johnson
# 5         6                         The Avengers              Joss Whedon  2012     1518.8           Blockbuster       Seamus McGarvey
# 6         7                           Iron Man 3              Shane Black  2013     1215.4           Blockbuster             John Toll
# 7         8                 Thor: The Dark World              Alan Taylor  2013      644.8               Average     Kramer Morgenthau
# 8         9  Captain America: The Winter Soldier           Russo Brothers  2014      714.4              Superhit         Trent Opaloch
# 9        10              Guardians of the Galaxy               James Gunn  2014      773.3           Blockbuster             Ben Davis
# 10       11              Avengers: Age of Ultron              Joss Whedon  2015     1405.4           Blockbuster             Ben Davis
# 11       12                              Ant-Man              Peyton Reed  2015      519.3                   Hit     Russell Carpenter
# 12       13           Captain America: Civil War           Russo Brothers  2016     1153.3           Blockbuster         Trent Opaloch
# 13       14                       Doctor Strange         Scott Derrickson  2016      677.8              Superhit             Ben Davis
# 14       15       Guardians of the Galaxy Vol. 2               James Gunn  2017      869.0              Superhit          Henry Braham
# 15       16               Spider-Man: Homecoming                Jon Watts  2017      880.2              Superhit      Salvatore Totino
# 16       17                       Thor: Ragnarok            Taika Waititi  2017      854.0           Blockbuster  Javier Aguirresarobe
# 17       18                        Black Panther             Ryan Coogler  2018     1347.1           Blockbuster       Rachel Morrison
# 18       19               Avengers: Infinity War           Russo Brothers  2018     2048.4           Blockbuster         Trent Opaloch
# 19       20                 Ant-Man and the Wasp              Peyton Reed  2018      622.7                   Hit        Dante Spinotti
# 20       21                       Captain Marvel  Anna Boden & Ryan Fleck  2019     1128.3              Superhit             Ben Davis
# 21       22                    Avengers: Endgame           Russo Brothers  2019     2797.8  All Time Blockbuster         Trent Opaloch
# 22       23           Spider-man :Far From Home                John Watts  2019     1110.0                   NaN                   NaN

# %% [markdown]
# Compare box office of marvel vs DC

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)

df_marvel["Universe"] = "Marvel"
df_dc["Universe"] = "DC"
marvel_dc = pd.concat([df_marvel, df_dc], axis = 0)

marvel_dc.groupby("Universe")["BoxOffice"].sum()
# Out:
# Universe
# DC         8856.0
# Marvel    22574.4
# Name: BoxOffice, dtype: float64

# %% [markdown]
# Director with Highest box office in Marvel

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)

df_marvel.groupby("director")["BoxOffice"].sum().sort_values(ascending = False).head(10)
# Out:
# director
# Russo Brothers             6713.9
# Joss Whedon                2924.2
# James Gunn                 1642.3
# Ryan Coogler               1347.1
# Shane Black                1215.4
# Jon Favreau                1209.7
# Peyton Reed                1142.0
# Anna Boden & Ryan Fleck    1128.3
# John Watts                 1110.0
# Jon Watts                   880.2
# Name: BoxOffice, dtype: float64

# %% [markdown]
# How many dc movies flop

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)


df_dinfo.query("verdict == 'Flop'").shape[0]
# Out:
# 1

# %% [markdown]
# TOP 3 MARVEL MOVIES WITH VERDICT , RLEASE YEAR AND DIRECTOR

# %%
import pandas as pd

from sqlalchemy import create_engine

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)



engine = create_engine('mysql+mysqlconnector://root:harsh009%40@127.0.0.1:3306/titanic')

df_marvel = pd.read_sql("SELECT * FROM marvel", con=engine)
df_minfo = pd.read_sql("SELECT * FROM marvel_info", con=engine)

df_dc = pd.read_sql("SELECT * FROM dc", con=engine)
df_dinfo = pd.read_sql("SELECT * FROM dc_info", con=engine)

df_marvelall = pd.merge(df_marvel, df_minfo, on="movieid", how = "left")


df_marvelall[["title","year","verdict","BoxOffice"]].sort_values(by="BoxOffice", ascending=False).head(3)
# Out:
#                      title  year               verdict  BoxOffice
# 21       Avengers: Endgame  2019  All Time Blockbuster     2797.8
# 18  Avengers: Infinity War  2018           Blockbuster     2048.4
# 5             The Avengers  2012           Blockbuster     1518.8
